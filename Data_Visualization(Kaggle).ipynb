# %% [markdown]
# <a href="https://colab.research.google.com/github/Sundaram-2001/Data-Analysis/blob/main/Data_Visualization(Kaggle).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("Setup Complete!")
# Out:
# Setup Complete!

# %%
data=pd.read_csv('/content/insurance.csv')

# %%
data_df=pd.DataFrame(data)

# %%
data_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Now we explore the dataset i.e. we use methods like head(),tail(),info(),describe() etc to get insights from the dataset

# %%
data_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data_df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
data_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
plt.figure(figsize=(16,10))
sns.lineplot(data=data_df,color='black')

# %% [markdown]
# Line Charts

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv('/content/spotify.csv', index_col="Date", parse_dates=True)

# %%
data1
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %% [markdown]
# Notice that the first date that appears is January 6, 2017, corresponding to the release date of "The Shape of You", by Ed Sheeran. And, using the table, you can see that "The Shape of You" was streamed 12,287,078 times globally on the day of its release. Notice that the other songs have missing values in the first row, because they weren't released until later!

# %% [markdown]
# In the below cells we explore the dataset by using methods like head(),tail(),info(),describe() etc...

# %%
data.head()
#data.tail()
#d#ata.describe()
#data.info()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
sns.lineplot(data=data)
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14,6))
plt.title("Daily global stream of popular tracks in 2017-2018")
sns.lineplot(data=data1)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,20))
plt.title("Daily global streams of popular tracks of 2017-2018")
#sns.lineplot(data=data1['Shape of You'])
sns.lineplot(data=data1['Something Just Like This'])
sns.lineplot(data=data1['Shape of You'])
plt.xlabel("Date")
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.title("Daily global streams of popular tracks of 2017-2018")
plt.xlabel("Date")
sns.lineplot(data=data1['Something Just Like This'],label="Somethin Just Like This")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data2=pd.read_csv('/content/museum-visitors.csv')

# %%
data2
# Out:
#                       Month  America Tropical Interpretive Center  \
# 0   2014-01-01T00:00:00.000                                  6602
# 1   2014-02-01T00:00:00.000                                  5029
# 2   2014-03-01T00:00:00.000                                  8129
# 3   2014-04-01T00:00:00.000                                  2824
# 4   2014-05-01T00:00:00.000                                 10694
# ..                      ...                                   ...
# 85  2021-02-01T00:00:00.000                                     0
# 86  2021-03-01T00:00:00.000                                     0
# 87  2021-04-01T00:00:00.000                                     0
# 88  2021-05-01T00:00:00.000                                     0
# 89  2021-06-01T00:00:00.000                                  1047
#
#     Avila Adobe  Chinese American Museum  Gateway to Nature Center  \
# 0         24778                     1581                       NaN
# ...

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=data2)

# %%
plt.figure(figsize=(12,9))
sns.lineplot(data=data2['Avila Adobe'],label="Avila Adobe")
sns.lineplot(data=data2['Gateway to Nature Center'],label="gateway")
plt.title("Visitors at Avila Adobe and Firehouse Museum")
plt.xlabel("Month")
#plt.ylabel("Gateway to Nature Center")
plt.show()

# %% [markdown]
# BarPlot and HeatMaps

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_df=pd.read_csv('/content/flight_delays.csv',index_col="Month")

# %%
data_df
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
data_df.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
data_df.tail()
# Out:
#              AA        AS         B6        DL        EV         F9        HA  \
# Month
# 8      3.193907  2.503899   9.280950  0.653114  5.154422   9.175737  7.448029
# 9     -1.432732 -1.813800   3.539154 -3.703377  0.851062   0.978460  3.696915
# 10    -0.580930 -2.993617   3.676787 -5.011516  2.303760   0.082127  0.467074
# 11     0.772630 -1.916516   1.418299 -3.175414  4.415930  11.164527 -2.719894
# 12     4.149684 -1.846681  13.839290  2.504595  6.685176   9.346221 -1.706475
#
#              MQ         NK         OO        UA  US         VX        WN
# Month
# 8      1.896565  20.519018   5.606689  5.014041 NaN   5.106221  5.532108
# 9     -2.167268   8.000101   1.530896 -1.794265 NaN   0.070998 -1.336260
# 10    -3.735054   6.810736   1.750897 -2.456542 NaN   2.254278 -0.688851
# 11     0.220061   7.543881   4.925548  0.281064 NaN   0.116370  0.995684
# 12     0.662486  12.733123  10.947612  7.012079 NaN  13.498720  6.720893

# %%
data_df.info(
    
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 1 to 12
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AA      12 non-null     float64
#  1   AS      12 non-null     float64
#  2   B6      12 non-null     float64
#  3   DL      12 non-null     float64
#  4   EV      12 non-null     float64
#  5   F9      12 non-null     float64
#  6   HA      12 non-null     float64
#  7   MQ      12 non-null     float64
#  8   NK      12 non-null     float64
#  9   OO      12 non-null     float64
#  10  UA      12 non-null     float64
#  11  US      6 non-null      float64
#  12  VX      12 non-null     float64
#  13  WN      12 non-null     float64
# dtypes: float64(14)
# memory usage: 1.4 KB

# %%
data_df.describe()
# Out:
#               AA         AS         B6         DL         EV         F9  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean    4.120776  -1.023656   6.788370   0.231116   6.543328  13.035736
# std     3.157890   1.544310   5.543460   3.247467   3.506834   7.844315
# min    -1.432732  -3.009003  -0.709019  -5.011516   0.851062   0.082127
# 25%     2.588588  -1.864140   3.349392  -2.326739   4.719922   9.303600
# 50%     4.540731  -1.249661   5.444304   0.401224   6.707638  12.823997
# 75%     6.759151  -0.295821   9.646042   2.184623   7.927592  18.696167
# max     8.191017   2.503899  18.657673   5.614745  13.952793  27.424179
#
#               HA         MQ         NK         OO         UA        US  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000  6.000000
# mean    1.993205   5.964953  14.549663   5.909658   5.413415  3.776815
# std     2.987726   7.780334   8.319500   3.380527   5.281123  2.305290
# ...

# %%
plt.figure(figsize=(12,6))
plt.title("Average Delay Time of Spirit Airlines,by Month")
sns.barplot(x=data_df.index,y=data_df['NK'])
plt.ylabel("Average Delay time in minutes")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.title("Average Delay Time of American Eagle,by Month")
sns.barplot(x=data_df.index,y=data_df['AA'])
plt.ylabel("Average Delay time in minutes")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.title("Average Delay Time of Alaska Airlines,by Month")
sns.barplot(x=data_df.index,y=data_df['AS'])
plt.ylabel("Average Delay time in minutes")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.title("Average Delay Time of Delta Airlines,by Month")
sns.barplot(x=data_df.index,y=data_df['DL'])
plt.ylabel("Average Delay time in minutes")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
flight_data=pd.read_csv('/content/flight_delays.csv')
flight_data
# Out:
#     Month        AA        AS         B6        DL         EV         F9  \
# 0       1  6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 1       2  7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 2       3  6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 3       4  4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 4       5  5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 5       6  8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 6       7  3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 7       8  3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 8       9 -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 9      10 -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 10     11  0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 11     12  4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
plt.figure(figsize=(14,7))
plt.title("HeatMap Representation")
sns.heatmap(data=flight_data,annot=True)
plt.xlabel("Airlines")
plt.show()

# %% [markdown]
#  if we look closely, the months toward the end of the year (especially months 9-11) appear relatively dark for all airlines. This suggests that airlines are better (on average) at keeping schedule during these months!

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the Dataset in the cell below

# %%
data=pd.read_csv('/content/insurance.csv')
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.scatterplot(x=data['bmi'],y=data['charges'])

# %% [markdown]
# The scatterplot above suggests that body mass index (BMI) and insurance charges are positively correlated, where customers with higher BMI typically also tend to pay more in insurance costs. (This pattern makes sense, since high BMI is typically associated with higher risk of chronic disease.)
#
# To double-check the strength of this relationship, you might like to add a regression line, or the line that best fits the data. We do this by changing the command to sns.regplot.

# %%
sns.regplot(x=data['bmi'],y=data['charges'])

# %%
sns.scatterplot(x=data['bmi'],y=data['charges'],hue=data['sex'])

# %%
sns.scatterplot(x=data['bmi'],y=data['charges'],hue=data['region'])

# %%
sns.lmplot(x="bmi",y="charges", data=data,hue="smoker")

# %%
sns.swarmplot(x=data['charges'],y=data['smoker'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 68.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x=data['charges'],y=data['region'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 43.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 39.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 41.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 39.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x=data['charges'],y=data['sex'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 41.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 36.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris_data=pd.read_csv('/content/iris.csv')
iris_data
# Out:
#       Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0      1                5.1               3.5                1.4
# 1      2                4.9               3.0                1.4
# 2      3                4.7               3.2                1.3
# 3      4                4.6               3.1                1.5
# 4      5                5.0               3.6                1.4
# ..   ...                ...               ...                ...
# 145  146                6.7               3.0                5.2
# 146  147                6.3               2.5                5.0
# 147  148                6.5               3.0                5.2
# 148  149                6.2               3.4                5.4
# 149  150                5.9               3.0                5.1
#
#      Petal Width (cm)         Species
# 0                 0.2     Iris-setosa
# 1                 0.2     Iris-setosa
# 2                 0.2     Iris-setosa
# ...

# %%
iris_data.head()
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa

# %%
iris_data.tail()
# Out:
#       Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 145  146                6.7               3.0                5.2
# 146  147                6.3               2.5                5.0
# 147  148                6.5               3.0                5.2
# 148  149                6.2               3.4                5.4
# 149  150                5.9               3.0                5.1
#
#      Petal Width (cm)         Species
# 145               2.3  Iris-virginica
# 146               1.9  Iris-virginica
# 147               2.0  Iris-virginica
# 148               2.3  Iris-virginica
# 149               1.8  Iris-virginica

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 150 non-null    int64
#  1   Sepal Length (cm)  150 non-null    float64
#  2   Sepal Width (cm)   150 non-null    float64
#  3   Petal Length (cm)  150 non-null    float64
#  4   Petal Width (cm)   150 non-null    float64
#  5   Species            150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_data.describe()
# Out:
#                Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# count  150.000000         150.000000        150.000000         150.000000
# mean    75.500000           5.843333          3.054000           3.758667
# std     43.445368           0.828066          0.433594           1.764420
# min      1.000000           4.300000          2.000000           1.000000
# 25%     38.250000           5.100000          2.800000           1.600000
# 50%     75.500000           5.800000          3.000000           4.350000
# 75%    112.750000           6.400000          3.300000           5.100000
# max    150.000000           7.900000          4.400000           6.900000
#
#        Petal Width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
sns.distplot(a=iris_data['Petal Length (cm)'],kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(data=iris_data['Petal Length (cm)'],shade=True)

# %%
iris_setosa_data=pd.read_csv('/content/iris_setosa.csv')
iris_versicolor_data=pd.read_csv('/content/iris_versicolor.csv')
iris_virginica_data=pd.read_csv('/content/iris_virginica.csv')

# %%
iris_setosa_data
# Out:
#     Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0    1                5.1               3.5                1.4
# 1    2                4.9               3.0                1.4
# 2    3                4.7               3.2                1.3
# 3    4                4.6               3.1                1.5
# 4    5                5.0               3.6                1.4
# 5    6                5.4               3.9                1.7
# 6    7                4.6               3.4                1.4
# 7    8                5.0               3.4                1.5
# 8    9                4.4               2.9                1.4
# 9   10                4.9               3.1                1.5
# 10  11                5.4               3.7                1.5
# 11  12                4.8               3.4                1.6
# 12  13                4.8               3.0                1.4
# 13  14                4.3               3.0                1.1
# ...

# %%
iris_virginica_data
# Out:
#      Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   101                6.3               3.3                6.0
# 1   102                5.8               2.7                5.1
# 2   103                7.1               3.0                5.9
# 3   104                6.3               2.9                5.6
# 4   105                6.5               3.0                5.8
# 5   106                7.6               3.0                6.6
# 6   107                4.9               2.5                4.5
# 7   108                7.3               2.9                6.3
# 8   109                6.7               2.5                5.8
# 9   110                7.2               3.6                6.1
# 10  111                6.5               3.2                5.1
# 11  112                6.4               2.7                5.3
# 12  113                6.8               3.0                5.5
# 13  114                5.7               2.5                5.0
# ...

# %%
iris_versicolor_data
# Out:
#      Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0    51                7.0               3.2                4.7
# 1    52                6.4               3.2                4.5
# 2    53                6.9               3.1                4.9
# 3    54                5.5               2.3                4.0
# 4    55                6.5               2.8                4.6
# 5    56                5.7               2.8                4.5
# 6    57                6.3               3.3                4.7
# 7    58                4.9               2.4                3.3
# 8    59                6.6               2.9                4.6
# 9    60                5.2               2.7                3.9
# 10   61                5.0               2.0                3.5
# 11   62                5.9               3.0                4.2
# 12   63                6.0               2.2                4.0
# 13   64                6.1               2.9                4.7
# ...

# %%
sns.distplot(a=iris_setosa_data['Petal Length (cm)'],label="iris-setosa",kde=False)
sns.distplot(a=iris_versicolor_data['Petal Length (cm)'],label="iris-versicolor",kde=False)
sns.distplot(a=iris_virginica_data['Petal Length (cm)'],label="iris-verginica",kde=False)
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(data=iris_setosa_data['Petal Length (cm)'],label="iris-setosa",shade=True)
sns.kdeplot(data=iris_versicolor_data['Petal Length (cm)'],label="iris-versicolor",shade=True)
sns.kdeplot(data=iris_virginica_data['Petal Length (cm)'],label="iris-verginica",shade=True)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
spotify_data=pd.read_csv('/content/spotify.csv')

# %%
spotify_data
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# ...

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=spotify_data)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=spotify_data)
sns.set_style("darkgrid")
plt.legend()
plt.show()
#sns.set_style("dark")
